# %%
from pykml import parser
import numpy as np
import pandas as pd
from ll_xy import lonlat_to_xy
import matplotlib.pyplot as plt
from netCDF4 import Dataset
import cartopy.crs as ccrs
import cartopy
import shapely

with open('../../flade.kml', 'r') as f:
    root = parser.parse(f).getroot()
    
namespace = {"kml": 'http://www.opengis.net/kml/2.2'}
pms = root.xpath(".//kml:Placemark[.//kml:Polygon]", namespaces=namespace)


x = str(pms[0].Polygon.outerBoundaryIs.LinearRing.coordinates)

# %%
x = x.replace('\t','')
x = x.replace('\n','')
x = x.replace('0 ','')
x = x[:-1]
coords = x.split(',')
lats = np.array([float(n) for n in coords[1::2]])
lons = np.array([float(n) for n in coords[0::2]])

xpoly,ypoly = lonlat_to_xy(lons,lats,hemisphere='n')
dfpoly = pd.DataFrame({'x':xpoly,'y':ypoly,'lons':lons,'lats':lats})
dfpoly.to_csv('Flade_poly_coords.csv')

# %%
np.nanmin(lats),np.nanmax(lats),np.nanmin(lons),np.nanmax(lons)
# Out:
# (80.8003496237128, 81.79504077375327, -18.50749931075323, -11.571139837805)

# %%
plt.plot(xpoly,ypoly,marker='o')

# %%
import cdsapi

dataset = "reanalysis-era5-single-levels"
request = {
    "product_type": ["reanalysis"],
    "variable": ["mean_sea_level_pressure"],
    "year": ["2021"],
                'area': [
                83, -23, 79,
                -10,
            ],
    "month": ["02"],
    "day": ["02","03"],
    "time": ["09:00"],
    "data_format": "netcdf",
    "download_format": "unarchived"
}

client = cdsapi.Client()
client.retrieve(dataset, request).download("flade.nc")
# Out:
# 2025-01-13 16:49:30,700 WARNING [2025-01-08T00:00:00] Please be informed that Beta URL (cds-beta) have been now discontinued. If you still need to migrate, please follow [available instructions here](https://forum.ecmwf.int/t/goodbye-legacy-climate-data-store-hello-new-climate-data-store-cds/6380)
# 2025-01-13 16:49:30,702 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2025-01-13 16:49:30,704 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-01-13 16:49:30,706 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2025-01-13 16:49:30,708 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2025-01-13 16:49:31,451 INFO [2025-01-09T00:00:00] Please be aware that ERA5 data from 1st January 2025 was degraded and is being corrected. Watch the [Forum announcement](https://forum.ecmwf.int/t/era5-data-from-1st-january-2025-was-degraded-and-is-being-corrected/10689) for updates.
# 2025-01-13 16:49:31,452 INFO Request ID is 2f95f43b-16d4-4b8d-b7e5-ab78f1da0e59
# 2025-01-13 16:49:31,572 INFO status has been updated to accepted
# 2025-01-13 16:49:40,280 INFO status has been updated to running
# 2025-01-13 16:49:45,778 INFO status has been updated to successful
# 50679935d6ef3fb251f687b06ed33405.nc:   0%|          | 0.00/27.5k [00:00<?, ?B/s]
# 'flade.nc'

# %%
d = Dataset('flade.nc')

lons = np.array(d['longitude'])
lats = np.array(d['latitude'])

latgrid = np.repeat(lats[:,np.newaxis],lons.shape[0],axis=1)
longrid = np.repeat(lons[np.newaxis,:],lats.shape[0],axis=0)

longrid.shape,latgrid.shape
# Out:
# ((17, 53), (17, 53))

# %%
fig = plt.figure(figsize=(6,6))
proj = ccrs.NorthPolarStereo()
ax = plt.axes(projection=proj)


ax.set_extent([-22, -2,84, 78], ccrs.PlateCarree())

ax.add_feature(cartopy.feature.COASTLINE,zorder=5)

cont = ax.pcolormesh(longrid,
                      latgrid,
                  np.array(d['msl'])[0],
                     # vmin=0,vmax=1,
                  transform=ccrs.PlateCarree())

cb = fig.colorbar(cont,shrink=0.8)
cb.set_label('MSL (hPa)',fontsize='x-large')
# fig.savefig('Ice_Edge_Jan25.png',dpi=400,bbox_inches='tight')

# %% [markdown]
# # Calculate which grid cells fall within polygon
#
# nan out ones which don't

# %%
x = np.array(d['msl'])[0]


polylons = np.array(dfpoly['lons'])
polylats = np.array(dfpoly['lats'])

poly_coords = [(x,y) for x,y in zip(dfpoly['x'],
                                    dfpoly['y'])]
polygon = shapely.Polygon(poly_coords)


xgrid,ygrid=lonlat_to_xy(longrid.flatten(),
                        latgrid.flatten(),
                        hemisphere='n')

pts = [shapely.geometry.Point(x,y) for x,y in zip(xgrid,ygrid)]

within = np.array([pt.within(polygon) for pt in pts])

mask = within.reshape(longrid.shape)

mask[mask<0]=np.nan

# %%
fig = plt.figure(figsize=(6,6))
proj = ccrs.NorthPolarStereo()
ax = plt.axes(projection=proj)


ax.set_extent([-22, -2,84, 78], ccrs.PlateCarree())

ax.add_feature(cartopy.feature.COASTLINE,zorder=5)

cont = ax.pcolormesh(longrid,
                      latgrid,
                  mask[:-1,:-1],
                     vmin=0,vmax=1,
                  transform=ccrs.PlateCarree())

cb = fig.colorbar(cont,shrink=0.8)
cb.set_label('MSL (hPa)',fontsize='x-large')
# fig.savefig('Ice_Edge_Jan25.png',dpi=400,bbox_inches='tight')
